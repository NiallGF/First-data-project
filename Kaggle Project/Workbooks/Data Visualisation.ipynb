# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/niallflaherty/Documents/GitHub/Practise-Code/Kaggle Project/Data/supermarket_sales_clean.csv')

# %%
df_sales_by_gender = df.groupby('Gender')['Total'].sum()
df_sales_by_gender.plot(kind='bar', color=['blue', 'pink'])
plt.title('Sales By Gender')
plt.xlabel('Gender')
plt.ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
df_sales_by_city = df.groupby('City')['Total'].sum()
df_sales_by_city.plot(kind='bar', color=['blue', 'pink', 'green'])
plt.title('Sales By City')
plt.xlabel('City')
plt.ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
df_Naypyitaw = df[df['City'] == 'Naypyitaw']
df_Naypyitaw_sales_by_gender = df_Naypyitaw['Gender'].value_counts()

df_Naypyitaw_sales_by_gender.plot(kind='bar', color=['pink', 'blue'])
plt.title('Gender Sales in Naypyitaw')
plt.xlabel('Gender')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %%
df_Mandalay = df[df['City'] == 'Mandalay']
df_Mandalay_sales_by_gender = df_Mandalay['Gender'].value_counts()

df_Mandalay_sales_by_gender.plot(kind='bar', color=['blue', 'pink'])
plt.title('Gender Sales in Mandalay')
plt.xlabel('Gender')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %%
df_Yangon = df[df['City'] == 'Yangon']
df_Yangon_sales_by_gender = df_Yangon['Gender'].value_counts()

df_Yangon_sales_by_gender.plot(kind='bar', color=['blue', 'pink'])
plt.title('Gender Sales in Yangon')
plt.xlabel('Gender')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %% [markdown]
# RESEARCH WHAT WOMEN ARE BUYING AND ARE THESE ITEMS SOLD THE MOST IN LARGER TOWNS OR WHAT!

# %%
df_highest_purchased_category = df['Product line'].value_counts().head(5)
df_highest_purchased_category.plot(kind='bar', color=['blue', 'pink', 'green', 'red', 'purple'])
# Out:
# <Axes: xlabel='Product line'>

# %%
df_Female = df[df['Gender'] == 'Female']
df_catagory_female_purchases = df_Female['Product line'].value_counts()

df_catagory_female_purchases.plot(kind='bar', color=['blue', 'pink', 'green', 'red', 'purple', 'orange'])
plt.title('Product Lines Purchased By Females')
plt.xlabel('Product Line')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %%
df_Male = df[df['Gender'] == 'Male']
df_Male_top_catagories = df_Male['Product line'].value_counts().head(5)

df_Male_top_catagories.plot(kind='bar', color=['blue', 'pink', 'green', 'red', 'purple', 'orange']) 
plt.title('Product Lines Purchased By Males')
plt.xlabel('Product Line')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %%
df_Female_Naypyitaw = df_Female[df_Female['City'] == 'Naypyitaw']
df_catagory_female_purchases_Naypitaw = df_Female_Naypyitaw['Product line'].value_counts()

df_catagory_female_purchases_Naypitaw.plot(kind='bar', color=['blue', 'pink', 'green', 'red', 'purple', 'orange'])
plt.title('Product Lines Purchased By Females in Naypyitaw')
plt.xlabel('Product Line')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %%
df_Female_Yangon = df_Female[df_Female['City'] == 'Yangon']
df_catagory_female_purchases_Yangon = df_Female_Yangon['Product line'].value_counts()

df_catagory_female_purchases_Yangon.plot(kind='bar', color=['blue', 'pink', 'green', 'red', 'purple', 'orange'])
plt.title('Product Lines Purchased By Females in Yangon')
plt.xlabel('Product Line')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')

# %%
df_Female_Mandalay = df_Female[df_Female['City'] == 'Mandalay']
df_catagory_female_purchases_Mandalay = df_Female_Mandalay['Product line'].value_counts()

df_catagory_female_purchases_Mandalay.plot(kind='bar', color=['blue', 'pink', 'green', 'red', 'purple', 'orange'])
plt.title('Product Lines Purchased By Females in Mandalay')
plt.xlabel('Product Line')
plt.ylabel('Sales Counts')
# Out:
# Text(0, 0.5, 'Sales Counts')
