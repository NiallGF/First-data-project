# %%
import pandas as pd
import numpy as np

from pandas import DataFrame

df = pd.read_csv('Book1.csv')

# %%
df['Total Amount'] = df['Total Amount'].replace('[£,]', '', regex=True).astype(float)
orders_minus_china = df[df['Country'] != 'China']
orders_with_value = orders_minus_china[orders_minus_china['Total Amount'] > 0]
orders_by_country = orders_with_value.groupby('Country').size()
orders_by_country.plot(kind='bar', title='Mean Order Amount by Country')
# Out:
# <Axes: title={'center': 'Mean Order Amount by Country'}, xlabel='Country'>
